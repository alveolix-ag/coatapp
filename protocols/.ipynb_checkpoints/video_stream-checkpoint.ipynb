# %%
from opentrons import labware, instruments, robot, containers
import signal
import sys
import math
import pickle
import subprocess
import os
import time
import io
import base64
from IPython.display import HTML

#if not robot.is_simulating():
#pro = subprocess.Popen(['ffmpeg', '-y', '-video_size', '720x480', '-i', '/dev/video0', '-vf', '\"transpose=2,transpose=2\"', 'videotest.mp4'])
pro = subprocess.Popen(['ffmpeg', '-y', '-video_size', '720x480', '-i', '/dev/video0', 'videotest121.mp4'])
#command = 'ffmpeg -y -video_size 720x480 -i /dev/video0 -vf "transpose=2,transpose=2" videotest3.mp4'
#pro = subprocess.Popen(command)
# ffmpeg -y -video_size 720x480 -i /dev/video0 -vf "transpose=2,transpose=2" videotest3.mp4

time.sleep(20)

robot.connect()
robot.home()

time.sleep(80)
#os.killpg(os.getpgid(pro.pid), signal.SIGTERM) 

pro.terminate()

# %%
video = io.open('videotest121.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
